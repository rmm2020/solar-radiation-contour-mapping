# %% [markdown]
# # Set up sqlite database

# %%
import sqlite3

# %%
conn = sqlite3.connect('GeoPVWattData.db')
c = conn.cursor()

# %%
#sql = """DROP TABLE LatLonData"""
# sql = """CREATE TABLE LatLonData(
#         lat real,
#         lon real,
#         city text,
#         state text,
#         tilt real,
#         azimuth real,
#         azimuthname text,
#         solrad_jan real,
#         solrad_feb real,
#         solrad_mar real,
#         solrad_apr real,
#         solrad_may real,
#         solrad_jun real,
#         solrad_jul real,
#         solrad_aug real,
#         solrad_sep real,
#         solrad_oct real,
#         solrad_nov real,
#         solrad_dec real,
#         solrad_average real,
#         solrad_minus real,
#         solrad_plus real,
#         solrad_annual real,
#         PRIMARY KEY (lat, lon, tilt, azimuth)
#         )"""

# sql = """INSERT INTO LanLonData VALUES ()
# """

# sql = """ALTER TABLE LatLonData ADD country text"""

# sql = """UPDATE LatLonData SET country = 'United States'"""
sql = """SELECT * FROM LatLonData"""

c.execute(sql)
df=c.fetchall()
print(df)
conn.commit()
conn.close()
# Out:
# [(37.617, -122.4, '"SAN FRANCISCO INTL AP"', 'CA', 0.0, 0.0, 'N', 2.138, 3.18, 4.407, 5.675, 6.424, 7.153, 7.124, 6.377, 5.468, 3.764, 2.531, 2.131, 4.698, 2.567, 2.455, 4.698, 'United States'), (37.617, -122.4, '"SAN FRANCISCO INTL AP"', 'CA', 90.0, 0.0, 'N', 0.636, 0.865, 0.984, 1.319, 1.488, 1.752, 1.843, 1.514, 1.152, 0.987, 0.718, 0.625, 1.157, 0.531, 0.686, 1.157, 'United States'), (37.617, -122.4, '"SAN FRANCISCO INTL AP"', 'CA', 90.0, 45.0, 'NE', 0.69, 1.021, 1.372, 2.05, 2.34, 2.726, 2.652, 2.318, 1.647, 1.254, 0.809, 0.668, 1.629, 0.961, 1.097, 1.629, 'United States'), (37.617, -122.4, '"SAN FRANCISCO INTL AP"', 'CA', 90.0, 90.0, 'E', 1.352, 1.906, 2.375, 3.01, 3.158, 3.474, 3.422, 3.307, 2.77, 2.278, 1.678, 1.473, 2.517, 1.165, 0.957, 2.517, 'United States'), (37.617, -122.4, '"SAN FRANCISCO INTL AP"', 'CA', 90.0, 135.0, 'SE', 2.401, 3.064, 3.225, 3.288, 3.062, 3.098, 3.251, 3.519, 3.645, 3.332, 2.902, 2.855, 3.137, 0.736, 0.508, 3.137, 'United States'), (37.617, -122.4, '
# ...
